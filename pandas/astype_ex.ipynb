# %% [markdown]
# # Concepts:
# - .astype()
# - .convert_dtypes()
# - .nbytes property
# - int8 / int16 / int64
# - .dtype property
#
# # Goal:
# Learn how different pandas data types affect memory
# usage and understand when converting dtypes can
# significantly reduce RAM consumption.

# %% [markdown]
# Part 1: Create a numeric Series and inspect memory usage

# %%
import pandas as pd
import numpy as np

int64_series = pd.Series([10, 20, 30, 40, 50])

print(int64_series)
print()

# TODO:
# Print the dtype of the Series.

# TODO:
# Print the number of bytes the Series consumes.
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# int64
# 40

# %% [markdown]
# Part 2: Convert to smaller integer types

# %%
# TODO:
# Convert the Series to int8 and have the variable nums_int8
# reference it.

# TODO:
# Print the dtype of int8_series.

# TODO:
# Print the memory usage of int8_series.

# Question:
# How does int8 use less memory than int64?

# Answer:
# int8 uses 8 bits for each integer.
# int64 uses 64 bits for each integer.
# Out:
# int8
# 5

# %% [markdown]
# Part 3: Trigger an integer overflow problem

# %%
# TODO:
# Create a Series containing the value 128.

# TODO:
# Attempt to convert it to int8.

# Question:
# What happens?

# Question:
# Why does int8 fail with 128?

# %% [markdown]
# Part 4: Use convert_dtypes()

# %%
df = pd.DataFrame({
    'age': [25, 30, 35],
    'name': ['Alice', 'Bob', 'Charlie'],
    'is_student': [True, False, True]
})

print("df.dtypes:\n", df.dtypes, sep="")

# TODO:
# Attempt to insert a missing value (pd.NA) into each column.
#
# Observe that:
# - The age column is coerced from int64 to float64.
# - The name column accepts pd.NA because it has an object dtype.
# - The is_student column raises a TypeError because bool
#   does not support pd.NA.

# TODO:
# Use .convert_dtypes() and store the result in df_converted.

# TODO:
# Print the new dtypes.

# TODO:
# Insert a missing value (pd.NA) into the is_student column
# of df_converted and verify that it works.
