# %% [markdown]
# <h3>Concepts:</h3>
# .astype() <br>
# .convert_dtypes() <br>
# .nbytes <br>
# int8 / int16 / int64 <br>
# category dtype
#
# <h3>Goal:</h3>
# Learn how different pandas data types affect memory <br>
# usage and understand when converting dtypes can <br>
# significantly reduce RAM consumption.

# %% [markdown]
# Part 1: Create a numeric Series and inspect memory usage.

# %%
import pandas as pd
import numpy as np

numbers = pd.Series([10, 20, 30, 40, 50])

print(numbers)
print()

# TODO:
# Print the dtype of the Series.

# TODO:
# Print the number of bytes using .nbytes.
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# Part 2: Convert to smaller integer types.

# %%
# TODO:
# Convert the Series to int8 and store it in numbers_int8.

# TODO:
# Print the dtype of numbers_int8.

# TODO:
# Print the memory usage of numbers_int8.

# Question:
# Why does int8 use less memory than int64?

# %% [markdown]
# Part 3: Trigger an overflow problem.

# %%
# TODO:
# Create a Series containing the value 128.

# TODO:
# Attempt to convert it to int8.

# QUESTION:
# What happens?

# QUESTION:
# Why does int8 fail with 128?

# %% [markdown]
# Part 4: Use convert_dtypes().

# %%
df = pd.DataFrame({
    'age': [25, 30, 35],
    'name': ['Alice', 'Bob', 'Charlie'],
    'is_student': [True, False, True]
})

print(df.dtypes)
print()

# TODO:
# Use .convert_dtypes() and store the result.

# TODO:
# Print the new dtypes.
