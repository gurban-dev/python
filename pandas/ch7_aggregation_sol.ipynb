# %% [markdown]
# <h4>Use the below data to complete the following problems.</h4>

# %%
import pandas as pd

state_wages = {
    "District of Columbia": 88000,
    "Massachusetts": 62270,
    "Washington": 61590,
    "Alaska": 59400,
    "New York": 58560,
    "Connecticut": 58400,
    "Maryland": 58050,
    "New Jersey": 57230,
    "California": 56940,
    "Rhode Island": 54040,
    "Minnesota": 53810,
    "Oregon": 53390,
    "Hawaii": 53260,
    "Virginia": 53020,
    "New Hampshire": 52610,
    "Vermont": 52410,
    "Delaware": 51030,
    "North Dakota": 50320,
    "Illinois": 50000,
    "Maine": 49440,
    "Wyoming": 49160,
    "Wisconsin": 48930,
    "Arizona": 48810,
    "Utah": 48600,
    "Pennsylvania": 48550,
    "Michigan": 48300,
    "Ohio": 48060,
    "Nebraska": 47990,
    "Iowa": 47670,
    "Texas": 47500,
    "Montana": 47360,
    "Georgia": 47020,
    "North Carolina": 46950,
    "Indiana": 46930,
    "Florida": 46860,
    "Kansas": 46850,
    "Idaho": 46470,
    "Nevada": 46440,
    "Missouri": 46390,
    "Tennessee": 46120,
    "New Mexico": 45870,
    "Kentucky": 45740,
    "South Dakota": 45620,
    "South Carolina": 44760,
    "Oklahoma": 43950,
    "Alabama": 43830,
    "Louisiana": 43770,
    "West Virginia": 43320,
    "Arkansas": 41020,
    "Mississippi": 39070
}

# %% [markdown]
# 1. Create a Pandas Series from the Python Dictionary
#
# Use state names as keys and median wages as values:

# %%
wage_series = pd.Series(state_wages, name="Median Wage")

# %%
wage_series
# Out:
# District of Columbia    88000
# Massachusetts           62270
# Washington              61590
# Alaska                  59400
# New York                58560
# Connecticut             58400
# Maryland                58050
# New Jersey              57230
# California              56940
# Rhode Island            54040
# Minnesota               53810
# Oregon                  53390
# Hawaii                  53260
# Virginia                53020
# New Hampshire           52610
# Vermont                 52410
# Delaware                51030
# North Dakota            50320
# Illinois                50000
# Maine                   49440
# Wyoming                 49160
# Wisconsin               48930
# Arizona                 48810
# Utah                    48600
# Pennsylvania            48550
# Michigan                48300
# Ohio                    48060
# Nebraska                47990
# Iowa                    47670
# Texas                   47500
# Montana                 47360
# Georgia                 47020
# North Carolina          46950
# Indiana                 46930
# Florida                 46860
# Kansas                  46850
# Idaho                   46470
# Nevada                  46440
# Missouri                46390
# Tennessee               46120
# New Mexico              45870
# Kentucky                45740
# South Dakota            45620
# South Carolina          44760
# Oklahoma                43950
# Alabama                 43830
# Louisiana               43770
# West Virginia           43320
# Arkansas                41020
# Mississippi             39070
# Name: Median Wage, dtype: int64

# %% [markdown]
# 2. Since dictionaries don't guarantee order in a meaningful way for analysis, <br>
#    the .sort_values() method with a particular keyword argument to see how <br>
#    the can be sorted in descending order.

# %%
wage_series = wage_series.sort_values(ascending=False)

# %% [markdown]
# 3. What is the average (mean) median wage across all states?
#
#    What is the highest median wage, and which state does it belong to?
#
#    What is the lowest median wage, and which state does it belong to?
#
#    How many total entries are in the dataset?
#
#    How many unique wage values are there?

# %% [markdown]
# 4. Find the following quantiles:
#    10th percentile
#
#    50th percentile (median)
#
#    90th percentile
#
#    What does the difference between the 10th and 90th percentile <br>
#    tell you about wage spread?

# %% [markdown]
# 5. How many states have a median wage above $50 000?
#
#    What percentage of states have a median wage above $50 000?
#
#    How many states fall below $45 000, and what percentage is that?

# %% [markdown]
# 6. Use .agg() to compute all of the following in a single line:
#
#    mean <br>
#    min <br>
#    max <br>
#    number of unique values <br>
#    standard deviation

# %% [markdown]
# 7. Is the wage distribution skewed toward higher or lower values?
#
#    Does the "average" wage reflect what most states actually earn?
#    Why or why not?
#
#    If you were choosing a state based purely on salary, would the
#    top state automatically be the best choice? What might be
#    missing from this data?

# %% [markdown]
# 8. Create a custom aggregation:
#    def wage_range(s):
#        return s.max() - s.min()
#
# Add this to .agg() and answer:
# - What is the total wage spread across states?
#
# - Is that spread large or small relative to the mean?
