# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Countries": ["Switzerland", "Norway", "Iceland"],
    'Human Development Index': [0.962, 0.961, 0.959]
})

# %%
df['Countries']
# Out:
# dtype('O')

# %% [markdown]
# float64 is a fixed 64-bit size across all platforms.

# %%
df['Human Development Index'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# int32 is more memory efficient because it uses half the memory as int64.

# %%
num: int = 2 * 10**12

# %%
num
# Out:
# 2000000000000

# %%
df['Human Development Index'].dtype
# Out:
# dtype('float64')

# %%
df['Human Development Index'] = df['Human Development Index'].astype('float32')

# %% [markdown]
# float128 has more precision than float16 because float128 uses 128 bits whereas float16 uses 16 bits.

# %%
df['Human Development Index'] = df['Human Development Index'].astype('float128')

# %%
df['Human Development Index'].dtype
# Out:
# dtype('float128')
