# %%
import pandas as pd

# %%
hdi = pd.Series(
    data=[0.972, 0.970, 0.970, 0.962, 0.959],
    index=["Iceland", "Norway", "Switzerland", "Denmark", "Germany"]
)

# %% [markdown]
# 1. Add the numeric series to itself.

# %% [markdown]
# 2. Add 10 to the numeric series.

# %% [markdown]
# 3. Add the numeric series to itself using the .add() method.
#
#    Also, write out how you would add the series to itself when
#    the indices do not perfectly match.

# %% [markdown]
# 4. Write an explanation of what the .add() method does.

# %% [markdown]
# 5. Fill in the missing code below to prevent the operation from returning NaN.

# %%
# Does 's2' have a matching index 'a' for 's1'?

# Does 's1' have a matching index 'c' for 's2'?

s1 = pd.Series([1, 2], index=['a', 'b'])

s2 = pd.Series([10, 20], index=['b', 'c'])

# %%
s1_s2_combination = s1.add(s2)

print("s1_s2_combination:\n", s1_s2_combination, sep="")

# %%
s1_s2_combination = s1.add(s2, fill_value=)

print("s1_s2_combination:\n", s1_s2_combination, sep="")
