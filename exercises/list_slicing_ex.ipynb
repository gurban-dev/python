# %% [markdown]
# Goal: Master slicing notation.
#
# Exercise:
#
# Given nums = [10, 20, 30, 40, 50, 60, 70]:
#
# Print the first 3 numbers.
#
# Print the last 2 numbers.
#
# Print every other number. (Example output: 10 30 50 70)
#
# Print the list reversed.
