# %% [markdown]
# Goal: Combine everything.
#
# Exercise:
#
# Create a list of numbers [3, 7, 12, 19, 25, 30, 42].
#
# Print:
#
# The length of the list.
#
# The sum of the numbers.
#
# The average (use float division).
#
# All numbers greater than 20.
#
# The list without the first and last element (slicing).
