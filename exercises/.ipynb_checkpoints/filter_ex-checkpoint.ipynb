# %% [markdown]
# Concepts:
# Filtering out rows from a Series
# Categorical Types
#
# 1. Using Jupyter, create a series with the temperature values for <br>
#    the last seven days.
#
#    Filter out the values below the mean.
#
# 2. Using Jupyter, create a series with your favorite colors.
#
#    Use a categorical type.
#
#    Inspect the categories by using the 'categories' attribute.
