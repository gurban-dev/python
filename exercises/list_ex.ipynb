# %% [markdown]
# Goal: Create and manipulate lists.
#
# Exercise:
#
# Make a list of 5 favorite foods.
#
# Print the first, third, and last item.
#
# Replace the second food with something new.
#
# Print the full list again.
