# %% [markdown]
# <h2>Part 1</h2>

# %% [markdown]
# **Import Pandas**

# %%
import pandas as pd

# %% [markdown]
# **Create a Series of Colours**

# %%
colours_series = pd.Series(['yellow', 'orange', 'purple'], name="Colours")

# %%
colours_series
# Out:
# 0    yellow
# 1    orange
# 2    purple
# Name: Colours, dtype: str

# %% [markdown]
# **Create a Series of Fruits**

# %%
fruits_series = pd.Series(['apricots', 'persimmons', 'figs'], name="Fruits")

# %%
fruits_series
# Out:
# 0      apricots
# 1    persimmons
# 2          figs
# Name: Fruits, dtype: str

# %% [markdown]
# **Merge them into a DataFrame**

# %%
df = pd.DataFrame({
    'Colours': colours_series,
    'Fruits': fruits_series
})

# %%
df
# Out:
#   Colours      Fruits
# 0  yellow    apricots
# 1  orange  persimmons
# 2  purple        figs

# %% [markdown]
# <h2>Part 2</h2>

# %% [markdown]
# Extracting one of the columns from the DataFrame.

# %%
df["Fruits"]
# Out:
# 0      apricots
# 1    persimmons
# 2          figs
# Name: Fruits, dtype: str

# %% [markdown]
# Data type of the returned column.

# %%
type(df["Fruits"])
# Out:
# pandas.Series
