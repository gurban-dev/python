# %% [markdown]
# <h2>Part 1</h2>
#
# <h3>Pandas Exercise: Creating Series</h3>
#
# <h3>Concepts:</h3>
#
# **Pandas Series** <br>
# **Pandas DataFrame**
#
# You will create two Series:
#
# A Series containing three colours.
#
# A Series containing three fruits that match those colours.
#
# For example:
#
# yellow -> apricots
#
# orange -> persimmons
#
# purple -> figs
#
# Display both Series.
#
# After creating the two Series, **merge them into a Pandas DataFrame** so <br>
# that one column contains the colours and the other contains the matching <br>
# fruits.
#
# Display the DataFrame.

# %% [markdown]
# <h2>Part 2</h2>

# %% [markdown]
# Show how you would extract one of the columns from the DataFrame.

# %% [markdown]
# Use a built-in Python function to reveal what the data type of the <br>
# returned column is.

# %% [markdown]
# Add a row with a fruit that has the same colour as one of the <br>
# existing fruits in the DataFrame.

# %% [markdown]
# Inspect the updated DataFrame.

# %% [markdown]
# Return only the rows that contain the duplicate colour.
