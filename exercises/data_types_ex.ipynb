# %% [markdown]
# Goal: Differentiate between int, float, str.
#
# Exercise:
#
# Create three variables:
#
# a_number = 42
#
# a_float = 3.14
#
# a_word = "Python"
#
# Print the type of each variable using type().
#
# Add a_number and a_float.
#
# Try adding a_number and a_word → observe error and fix it by converting with str().
