# %% [markdown]
# Goal: Iterate through lists.
#
# Exercise:
#
# Given colors = ["red", "blue", "green", "yellow"]:
#
# Print each color with the sentence: "Color: red" (etc).
#
# Count and print how many letters each color has.
