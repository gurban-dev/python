# %%
import numpy as np

# %%
a = np.array((1,2,3))

# %%
b = np.array((4,5,6))

# %% [markdown]
# -Stack arrays in sequence horizontally (column wise).

# %%
np.hstack((a,b))
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# -Explain the outcome here.

# %%
a = np.array([[1],[2],[3]])

# %%
b = np.array([[4],[5],[6]])

# %%
np.hstack((a,b))
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])
