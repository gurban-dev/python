# %%
import numpy as np

# %%
# Stock prices over ten days.
prices = np.array([100, 102, 101, 105, 103, 108, 107, 110, 109, 112])

# %% [markdown]
# Questions:
# 1. Calculate simple daily returns: (price[t] - price[t-1]) / price[t-1].
# 2. Calculate log returns: log(price[t] / price[t-1]).
# 3. Calculate cumulative return over the period.
# 4. Find the maximum daily gain and loss.
