# %%
import numpy as np

# %%
x = np.array([1, 2, 3])

# %%
x
# Out:
# array([1, 2, 3])

# %% [markdown]
# Declare a variable y and have it point to the same memory address that x points to.
#
# There is no copy being created in this case.

# %%
y = x

# %% [markdown]
# Make a deep copy of x and assign it to variable z.

# %%
deep_copy_of_x = np.copy(x)

# %%
y is x
# Out:
# True

# %%
x is y
# Out:
# True

# %% [markdown]
# Reveal the memory addresses of x, y, and deep_copy_of_x.

# %%
hex(id(x))
# Out:
# '0x7a20a8d5c210'

# %%
hex(id(y))
# Out:
# '0x7a20a8d5c210'

# %%
hex(id(deep_copy_of_x))
# Out:
# '0x7a20a8041bf0'

# %%
x[0] = 10

# %%
x
# Out:
# array([10,  2,  3])

# %%
y
# Out:
# array([10,  2,  3])

# %%
deep_copy_of_x
# Out:
# array([1, 2, 3])
