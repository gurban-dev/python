# %%
import numpy as np

# %%
ndarray1 = np.arange(0, 6, 1)

# %%
ndarray1
# Out:
# array([0, 1, 2, 3, 4, 5])

# %% [markdown]
# Reveal the memory address of ndarray1.

# %%
hex(id(ndarray1))
# Out:
# '0x7d7330142e50'

# %%
ndarray_reshaped = ndarray1.reshape(2, 3)

# %%
ndarray_reshaped
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %% [markdown]
# Reveal the memory address of ndarray_reshaped.

# %%
hex(id(ndarray_reshaped))
# Out:
# '0x7d7308768210'

# %% [markdown]
# reshape() and resize() can be contrasted by the fact that reshape() returns <br>
# a new view object (shallow copy) of the resize() returns None.
#
# Therefore, after invoking the resize() method on an ndarray object, <br>
# the result doesn't need to be assigned to be visualised.

# %%
ndarray1.resize(6, 1)

# %%
ndarray1
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %% [markdown]
# Reveal the memory address of ndarray1.

# %%
hex(id(ndarray1))
# Out:
# '0x7d7330142e50'
