# %%
import numpy as np

# %% [markdown]
# For this reason, it is usually better to use the function
#
# linspace that receives as an argument the number of elements
#
# that we want, instead of the step.

# %%
# 9 numbers from 0 to 2.
# Notice how the intervals between the numbers are
# of equal distance.
np.linspace(0, 2, 9)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  ])
